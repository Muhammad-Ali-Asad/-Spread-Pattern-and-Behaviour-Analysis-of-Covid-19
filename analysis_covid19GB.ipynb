# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file="COVID-19 Daily.xlsx"
#For Pakistan
data=pd.read_excel(file,sheet_name=["GB"])
data

# Access a specific sheet
data = data['GB']

# %%
# question1
null_values = data.isnull().sum()
column_info = data.info()
descriptive_stats = data.describe()

null_values, column_info, descriptive_stats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              188 non-null    datetime64[ns]
#  1   Daily Tests       175 non-null    float64
#  2   Daily Cases       178 non-null    float64
#  3   Daily Recoveries  175 non-null    float64
#  4   Daily Deaths      175 non-null    float64
#  5   Lockdown          49 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 8.9+ KB
# (Date                  0
#  Daily Tests          13
#  Daily Cases          10
#  Daily Recoveries     13
#  Daily Deaths         13
#  Lockdown            139
#  dtype: int64,
#  None,
#                        Date  Daily Tests  Daily Cases  Daily Recoveries  \
#  count                  188   175.000000   178.000000        175.000000
#  mean   2020-05-29 12:00:00   138.308571    16.308989         14.302857
#  min    2020-02-26 00:00:00     0.000000     0.000000          0.000000
#  25%    2020-04-12 18:00:00    69.500000     7.000000          3.000000
#  50%    2020-05-29 12:00:00   117.000000    14.000000         11.000000
#  75%    2020-07-15 06:00:00   172.500000    23.750000         21.000000
#  max    2020-08-31 00:00:00  2021.000000    53.000000         81.000000
#  std                    NaN   164.842547    12.529740         14.937600
#
#         Daily Deaths
#  count    175.000000
#  mean       0.382857
#  min        0.000000
#  25%        0.000000
#  50%        0.000000
#  75%        1.000000
#  max        3.000000
#  std        0.724563  )

# %%
# Fill missing values using forward fill and backward fill
data.fillna(method='ffill', inplace=True)
data.fillna(method='bfill', inplace=True)

# Re-check for missing values
print(data.isnull().sum())
# Out:
# Date                0
# Daily Tests         0
# Daily Cases         0
# Daily Recoveries    0
# Daily Deaths        0
# Lockdown            0
# dtype: int64
# C:\Users\malia\AppData\Local\Temp\ipykernel_17300\872869718.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# C:\Users\malia\AppData\Local\Temp\ipykernel_17300\872869718.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill', inplace=True)

# %%
# question02

total_tests = data['Daily Tests'].sum()
print(f'Total Tests Performed : {total_tests}')
# Out:
# Total Tests Performed : 24204.0

# %%
# Trend Line Graph
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Tests'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Tests'], color='purple')
plt.title('Scatter Plot of Daily Tests')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Tests'], color='orange')
plt.title('Bar Graph of Daily Tests')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()


average_tests = data['Daily Tests'].mean()

# Above-average in red, below-average in green
colors = ['red' if x > average_tests else 'green' for x in data['Daily Tests']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Tests'], color=colors)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Testing')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Trend Line Graph for Daily Cases
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Cases'], label='Daily Cases', color='blue')
plt.title('Daily Cases Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram for Daily Cases
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Cases'], color='purple')
plt.title('Scatter Plot of Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph for Daily Cases
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Cases'], color='orange')
plt.title('Bar Graph of Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Calculate average for daily cases
average_cases = data['Daily Cases'].mean()

# Color scheme: Above-average in red, below-average in green
colors_cases = ['red' if x > average_cases else 'green' for x in data['Daily Cases']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Cases'], color=colors_cases)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Trend Line Graph for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Recoveries'], label='Daily Recoveries', color='blue')
plt.title('Daily Recoveries Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Recoveries'], color='purple')
plt.title('Scatter Plot of Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Recoveries'], color='orange')
plt.title('Bar Graph of Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()


# Calculate average for daily recoveries
average_recoveries = data['Daily Recoveries'].mean()

# Color scheme: Above-average in red, below-average in green
colors_recoveries = ['red' if x > average_recoveries else 'green' for x in data['Daily Recoveries']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Recoveries'], color=colors_recoveries)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# question03

# Convert the dataset into weekly stats
weekly_stats = data.resample('W-Mon', on='Date').sum().reset_index().sort_values(by='Date')

# Convert the dataset into monthly stats
monthly_stats = data.resample('M', on='Date').sum().reset_index().sort_values(by='Date')

# Save the weekly and monthly stats
weekly_stats.to_excel('Weekly_StatsGB.xlsx', index=False)
monthly_stats.to_excel('Monthly_StatsGB.xlsx', index=False)

# Display max and min values for weekly and monthly stats
print("Weekly Stats - Max:")
print(weekly_stats.max())

print("Weekly Stats - Min:")
print(weekly_stats.min())

print("Monthly Stats - Max:")
print(monthly_stats.max())

print("Monthly Stats - Min:")
print(monthly_stats.min())
# Out:
# Weekly Stats - Max:
# Date                                              2020-08-31 00:00:00
# Daily Tests                                                    2936.0
# Daily Cases                                                     214.0
# Daily Recoveries                                                218.0
# Daily Deaths                                                      7.0
# Lockdown            lockdown1lockdown1lockdown1lockdown1lockdown1l...
# dtype: object
# Weekly Stats - Min:
# Date                                              2020-03-02 00:00:00
# Daily Tests                                                       0.0
# Daily Cases                                                       0.0
# Daily Recoveries                                                  0.0
# Daily Deaths                                                      0.0
# Lockdown            lockdown1lockdown1lockdown1lockdown1lockdown1l...
# dtype: object
# Monthly Stats - Max:
# Date                                              2020-08-31 00:00:00
# Daily Tests                                                    6329.0
# Daily Cases                                                     778.0
# Daily Recoveries                                                745.0
# Daily Deaths                                                     28.0
# Lockdown            lockdown1lockdown1lockdown1lockdown1lockdown1l...
# dtype: object
# Monthly Stats - Min:
# Date                                 2020-02-29 00:00:00
# Daily Tests                                          0.0
# Daily Cases                                          0.0
# Daily Recoveries                                     0.0
# Daily Deaths                                         0.0
# Lockdown            lockdown1lockdown1lockdown1lockdown1
# dtype: object
# C:\Users\malia\AppData\Local\Temp\ipykernel_17300\3013765692.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_stats = data.resample('M', on='Date').sum().reset_index().sort_values(by='Date')

# %%
# question04

population_million = 220

# Convert the 'Date' column to datetime format if not already
data['Date'] = pd.to_datetime(data['Date'])

# Calculate Per Thousand and Per Million stats
data['Tests per Thousand'] = (data['Daily Tests'] / population_million) / 1000
data['Cases per Thousand'] = (data['Daily Cases'] / population_million) / 1000
data['Recoveries per Thousand'] = (data['Daily Recoveries'] / population_million) / 1000
data['Deaths per Thousand'] = (data['Daily Deaths'] / population_million) / 1000

data['Tests per Million'] = (data['Daily Tests'] / population_million) * 1
data['Cases per Million'] = (data['Daily Cases'] / population_million) * 1
data['Recoveries per Million'] = (data['Daily Recoveries'] / population_million) * 1
data['Deaths per Million'] = (data['Daily Deaths'] / population_million) * 1

# Group by Month and aggregate the data
monthly_data = data.groupby(data['Date'].dt.to_period('M')).agg({
    'Daily Tests': 'sum',
    'Daily Cases': 'sum',
    'Tests per Thousand': 'sum',
    'Cases per Thousand': 'sum',
    'Tests per Million': 'sum',
    'Cases per Million': 'sum',
}).reset_index()

# Rename the 'Date' column to 'Month' and format it
monthly_data['Month'] = monthly_data['Date'].dt.strftime('%B')
monthly_data = monthly_data.drop(columns=['Date'])

# Calculate the positive rate
monthly_data['Positive Rate'] = (monthly_data['Daily Cases'] / monthly_data['Daily Tests']) * 100

# Rearrange the columns to match the format in the image
monthly_data = monthly_data[['Month', 'Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate']]



# Display the DataFrame as a formatted table
styled_table = monthly_data.style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', '#2d4154'), ('color', 'white')]}]
).background_gradient(cmap='Blues', subset=['Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate'])

# Show the styled DataFrame
styled_table
# Out:
# <style type="text/css">
# #T_286a7 thead th {
#   background-color: #2d4154;
#   color: white;
# }
# #T_286a7_row0_col1, #T_286a7_row0_col2, #T_286a7_row0_col3, #T_286a7_row0_col4, #T_286a7_row0_col5, #T_286a7_row0_col6, #T_286a7_row2_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_286a7_row0_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_286a7_row1_col1, #T_286a7_row1_col3, #T_286a7_row1_col5 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_286a7_row1_col2, #T_286a7_row1_col4, #T_286a7_row1_col6 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_286a7_row1_col7 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_286a7_row2_col1, #T_286a7_row2_col3, #T_286a7_row2_col5 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_286a7_row2_col2, #T_286a7_row2_col4, #T_286a7_row2_col6 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_286a7_row3_col1, #T_286a7_row3_col3, #T_286a7_row3_col5 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_286a7_row3_col2, #T_286a7_row3_col4, #T_286a7_row3_col6 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_286a7_row3_col7 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_286a7_row4_col1, #T_286a7_row4_col3, #T_286a7_row4_col5 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_286a7_row4_col2, #T_286a7_row4_col4, #T_286a7_row4_col6, #T_286a7_row5_col7, #T_286a7_row6_col1, #T_286a7_row6_col3, #T_286a7_row6_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_286a7_row4_col7 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_286a7_row5_col1, #T_286a7_row5_col3, #T_286a7_row5_col5 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_286a7_row5_col2, #T_286a7_row5_col4, #T_286a7_row5_col6 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_286a7_row6_col2, #T_286a7_row6_col4, #T_286a7_row6_col6 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_286a7_row6_col7 {
#   background-color: #97c6df;
#   color: #000000;
# }
# </style>
# <table id="T_286a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_286a7_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_286a7_level0_col1" class="col_heading level0 col1" >Daily Tests</th>
#       <th id="T_286a7_level0_col2" class="col_heading level0 col2" >Daily Cases</th>
#       <th id="T_286a7_level0_col3" class="col_heading level0 col3" >Tests per Thousand</th>
#       <th id="T_286a7_level0_col4" class="col_heading level0 col4" >Cases per Thousand</th>
#       <th id="T_286a7_level0_col5" class="col_heading level0 col5" >Tests per Million</th>
#       <th id="T_286a7_level0_col6" class="col_heading level0 col6" >Cases per Million</th>
#       <th id="T_286a7_level0_col7" class="col_heading level0 col7" >Positive Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_286a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_286a7_row0_col0" class="data row0 col0" >February</td>
#       <td id="T_286a7_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_286a7_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_286a7_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_286a7_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_286a7_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_286a7_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_286a7_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_286a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_286a7_row1_col0" class="data row1 col0" >March</td>
#       <td id="T_286a7_row1_col1" class="data row1 col1" >810.000000</td>
#       <td id="T_286a7_row1_col2" class="data row1 col2" >190.000000</td>
#       <td id="T_286a7_row1_col3" class="data row1 col3" >0.003682</td>
#       <td id="T_286a7_row1_col4" class="data row1 col4" >0.000864</td>
#       <td id="T_286a7_row1_col5" class="data row1 col5" >3.681818</td>
#       <td id="T_286a7_row1_col6" class="data row1 col6" >0.863636</td>
#       <td id="T_286a7_row1_col7" class="data row1 col7" >23.456790</td>
#     </tr>
#     <tr>
#       <th id="T_286a7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_286a7_row2_col0" class="data row2 col0" >April</td>
#       <td id="T_286a7_row2_col1" class="data row2 col1" >5106.000000</td>
#       <td id="T_286a7_row2_col2" class="data row2 col2" >155.000000</td>
#       <td id="T_286a7_row2_col3" class="data row2 col3" >0.023209</td>
#       <td id="T_286a7_row2_col4" class="data row2 col4" >0.000705</td>
#       <td id="T_286a7_row2_col5" class="data row2 col5" >23.209091</td>
#       <td id="T_286a7_row2_col6" class="data row2 col6" >0.704545</td>
#       <td id="T_286a7_row2_col7" class="data row2 col7" >3.035644</td>
#     </tr>
#     <tr>
#       <th id="T_286a7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_286a7_row3_col0" class="data row3 col0" >May</td>
#       <td id="T_286a7_row3_col1" class="data row3 col1" >4613.000000</td>
#       <td id="T_286a7_row3_col2" class="data row3 col2" >372.000000</td>
#       <td id="T_286a7_row3_col3" class="data row3 col3" >0.020968</td>
#       <td id="T_286a7_row3_col4" class="data row3 col4" >0.001691</td>
#       <td id="T_286a7_row3_col5" class="data row3 col5" >20.968182</td>
#       <td id="T_286a7_row3_col6" class="data row3 col6" >1.690909</td>
#       <td id="T_286a7_row3_col7" class="data row3 col7" >8.064166</td>
#     </tr>
#     <tr>
#       <th id="T_286a7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_286a7_row4_col0" class="data row4 col0" >June</td>
#       <td id="T_286a7_row4_col1" class="data row4 col1" >4881.000000</td>
#       <td id="T_286a7_row4_col2" class="data row4 col2" >778.000000</td>
#       <td id="T_286a7_row4_col3" class="data row4 col3" >0.022186</td>
#       <td id="T_286a7_row4_col4" class="data row4 col4" >0.003536</td>
#       <td id="T_286a7_row4_col5" class="data row4 col5" >22.186364</td>
#       <td id="T_286a7_row4_col6" class="data row4 col6" >3.536364</td>
#       <td id="T_286a7_row4_col7" class="data row4 col7" >15.939357</td>
#     </tr>
#     <tr>
#       <th id="T_286a7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_286a7_row5_col0" class="data row5 col0" >July</td>
#       <td id="T_286a7_row5_col1" class="data row5 col1" >2465.000000</td>
#       <td id="T_286a7_row5_col2" class="data row5 col2" >645.000000</td>
#       <td id="T_286a7_row5_col3" class="data row5 col3" >0.011205</td>
#       <td id="T_286a7_row5_col4" class="data row5 col4" >0.002932</td>
#       <td id="T_286a7_row5_col5" class="data row5 col5" >11.204545</td>
#       <td id="T_286a7_row5_col6" class="data row5 col6" >2.931818</td>
#       <td id="T_286a7_row5_col7" class="data row5 col7" >26.166329</td>
#     </tr>
#     <tr>
#       <th id="T_286a7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_286a7_row6_col0" class="data row6 col0" >August</td>
#       <td id="T_286a7_row6_col1" class="data row6 col1" >6329.000000</td>
#       <td id="T_286a7_row6_col2" class="data row6 col2" >769.000000</td>
#       <td id="T_286a7_row6_col3" class="data row6 col3" >0.028768</td>
#       <td id="T_286a7_row6_col4" class="data row6 col4" >0.003495</td>
#       <td id="T_286a7_row6_col5" class="data row6 col5" >28.768182</td>
#       <td id="T_286a7_row6_col6" class="data row6 col6" >3.495455</td>
#       <td id="T_286a7_row6_col7" class="data row6 col7" >12.150419</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Prepare data for ML models
X = data[['Daily Tests']]  # Feature (you can choose other features as well)
y_cases = data['Daily Cases']  # Target for cases
y_deaths = data['Daily Deaths']  # Target for deaths

# Split the data into training and testing sets
X_train, X_test, y_cases_train, y_cases_test = train_test_split(X, y_cases, test_size=0.2, random_state=42)
_, _, y_deaths_train, y_deaths_test = train_test_split(X, y_deaths, test_size=0.2, random_state=42)

# Linear Regression Model for Daily Cases
lr_model = LinearRegression()
lr_model.fit(X_train, y_cases_train)
cases_predictions = lr_model.predict(X_test)

# Random Forest Model for Daily Deaths
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_deaths_train)
deaths_predictions = rf_model.predict(X_test)

# Display the results
print(f"Linear Regression Model for Cases: {cases_predictions}")
print(f"Random Forest Model for Deaths: {deaths_predictions}")
# Out:
# Linear Regression Model for Cases: [17.21976362 15.21470535 13.32836763 13.38113232 15.25427887 16.24361683
#  14.30451442 15.03002893 13.38113232 14.119838   14.97726424 14.58152905
#  13.53942639 14.68705843 15.43895529 15.26747004 16.08532276 14.43642615
#  13.56580874 15.46533763 15.5312935  15.99298455 14.6079114  13.32836763
#  16.19085214 17.16699893 13.32836763 16.26999918 13.39432349 16.77126375
#  14.83216133 13.32836763 14.73982312 15.21470535 14.30451442 15.92702868
#  16.15127862 14.4100438 ]
# Random Forest Model for Deaths: [0.04       0.         0.         0.6        0.         0.83
#  1.64       0.146      0.6        0.         0.58       0.06
#  0.         2.514      0.         0.         0.72       0.08
#  0.05       0.         0.         0.63       0.12       0.
#  0.83       0.25       0.         1.51       0.26       0.02
#  0.07083333 0.         1.45866667 0.         1.64       0.13
#  0.34       0.89161905]
