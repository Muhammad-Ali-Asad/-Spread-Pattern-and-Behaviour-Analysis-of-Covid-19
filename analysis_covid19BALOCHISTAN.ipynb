# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file="COVID-19 Daily.xlsx"
#For Pakistan
data=pd.read_excel(file,sheet_name=["Balochistan"])
data

# Access a specific sheet
data = data['Balochistan']

# %%
# question1
null_values = data.isnull().sum()
column_info = data.info()
descriptive_stats = data.describe()

null_values, column_info, descriptive_stats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              188 non-null    datetime64[ns]
#  1   Daily Tests       175 non-null    float64
#  2   Daily Cases       177 non-null    float64
#  3   Daily Recoveries  175 non-null    float64
#  4   Daily Deaths      175 non-null    float64
#  5   Lockdown          47 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 8.9+ KB
# (Date                  0
#  Daily Tests          13
#  Daily Cases          11
#  Daily Recoveries     13
#  Daily Deaths         13
#  Lockdown            141
#  dtype: int64,
#  None,
#                        Date  Daily Tests  Daily Cases  Daily Recoveries  \
#  count                  188   175.000000   177.000000        175.000000
#  mean   2020-05-29 12:00:00   425.360000    72.762712         67.280000
#  min    2020-02-26 00:00:00     0.000000     0.000000          0.000000
#  25%    2020-04-12 18:00:00   212.500000    13.000000          2.500000
#  50%    2020-05-29 12:00:00   374.000000    48.000000         28.000000
#  75%    2020-07-15 06:00:00   577.500000    97.000000         88.000000
#  max    2020-08-31 00:00:00  1435.000000   501.000000        373.000000
#  std                    NaN   302.562849    86.555750         88.557965
#
#         Daily Deaths
#  count    175.000000
#  mean       0.800000
#  min        0.000000
#  25%        0.000000
#  50%        0.000000
#  75%        1.000000
#  max       11.000000
#  std        1.418272  )

# %%
# Fill missing values using forward fill and backward fill
data.fillna(method='ffill', inplace=True)
data.fillna(method='bfill', inplace=True)

# Re-check for missing values
print(data.isnull().sum())
# Out:
# Date                0
# Daily Tests         0
# Daily Cases         0
# Daily Recoveries    0
# Daily Deaths        0
# Lockdown            0
# dtype: int64
# C:\Users\malia\AppData\Local\Temp\ipykernel_19128\872869718.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# C:\Users\malia\AppData\Local\Temp\ipykernel_19128\872869718.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill', inplace=True)

# %%
# question02

total_tests = data['Daily Tests'].sum()
print(f'Total Tests Performed : {total_tests}')
# Out:
# Total Tests Performed : 74438.0

# %%
# Trend Line Graph
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Tests'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Tests'], color='purple')
plt.title('Scatter Plot of Daily Tests')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Tests'], color='orange')
plt.title('Bar Graph of Daily Tests')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()


average_tests = data['Daily Tests'].mean()

# Above-average in red, below-average in green
colors = ['red' if x > average_tests else 'green' for x in data['Daily Tests']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Tests'], color=colors)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Testing')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Trend Line Graph for Daily Cases
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Cases'], label='Daily Cases', color='blue')
plt.title('Daily Cases Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram for Daily Cases
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Cases'], color='purple')
plt.title('Scatter Plot of Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph for Daily Cases
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Cases'], color='orange')
plt.title('Bar Graph of Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Calculate average for daily cases
average_cases = data['Daily Cases'].mean()

# Color scheme: Above-average in red, below-average in green
colors_cases = ['red' if x > average_cases else 'green' for x in data['Daily Cases']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Cases'], color=colors_cases)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Trend Line Graph for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Recoveries'], label='Daily Recoveries', color='blue')
plt.title('Daily Recoveries Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Recoveries'], color='purple')
plt.title('Scatter Plot of Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Recoveries'], color='orange')
plt.title('Bar Graph of Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()


# Calculate average for daily recoveries
average_recoveries = data['Daily Recoveries'].mean()

# Color scheme: Above-average in red, below-average in green
colors_recoveries = ['red' if x > average_recoveries else 'green' for x in data['Daily Recoveries']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Recoveries'], color=colors_recoveries)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# question03

# Convert the dataset into weekly stats
weekly_stats = data.resample('W-Mon', on='Date').sum().reset_index().sort_values(by='Date')

# Convert the dataset into monthly stats
monthly_stats = data.resample('M', on='Date').sum().reset_index().sort_values(by='Date')

# Save the weekly and monthly stats
weekly_stats.to_excel('Weekly_StatsBalochistan.xlsx', index=False)
monthly_stats.to_excel('Monthly_StatsBalochistan.xlsx', index=False)

# Display max and min values for weekly and monthly stats
print("Weekly Stats - Max:")
print(weekly_stats.max())

print("Weekly Stats - Min:")
print(weekly_stats.min())

print("Monthly Stats - Max:")
print(monthly_stats.max())

print("Monthly Stats - Min:")
print(monthly_stats.min())
# Out:
# Weekly Stats - Max:
# Date                                              2020-08-31 00:00:00
# Daily Tests                                                    6947.0
# Daily Cases                                                    2340.0
# Daily Recoveries                                               1934.0
# Daily Deaths                                                     27.0
# Lockdown            lockdown4lockdown4lockdown4lockdown4lockdown4l...
# dtype: object
# Weekly Stats - Min:
# Date                                              2020-03-02 00:00:00
# Daily Tests                                                       0.0
# Daily Cases                                                       0.0
# Daily Recoveries                                                  0.0
# Daily Deaths                                                      0.0
# Lockdown            lockdown1lockdown1lockdown1lockdown1lockdown1l...
# dtype: object
# Monthly Stats - Max:
# Date                                              2020-08-31 00:00:00
# Daily Tests                                                   24154.0
# Daily Cases                                                    6083.0
# Daily Recoveries                                               5626.0
# Daily Deaths                                                     74.0
# Lockdown            lockdown4lockdown4lockdown4lockdown4lockdown4l...
# dtype: object
# Monthly Stats - Min:
# Date                                 2020-02-29 00:00:00
# Daily Tests                                          0.0
# Daily Cases                                          0.0
# Daily Recoveries                                     0.0
# Daily Deaths                                         0.0
# Lockdown            lockdown1lockdown1lockdown1lockdown1
# dtype: object
# C:\Users\malia\AppData\Local\Temp\ipykernel_19128\2692524687.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_stats = data.resample('M', on='Date').sum().reset_index().sort_values(by='Date')

# %%
# question04

population_million = 220

# Convert the 'Date' column to datetime format if not already
data['Date'] = pd.to_datetime(data['Date'])

# Calculate Per Thousand and Per Million stats
data['Tests per Thousand'] = (data['Daily Tests'] / population_million) / 1000
data['Cases per Thousand'] = (data['Daily Cases'] / population_million) / 1000
data['Recoveries per Thousand'] = (data['Daily Recoveries'] / population_million) / 1000
data['Deaths per Thousand'] = (data['Daily Deaths'] / population_million) / 1000

data['Tests per Million'] = (data['Daily Tests'] / population_million) * 1
data['Cases per Million'] = (data['Daily Cases'] / population_million) * 1
data['Recoveries per Million'] = (data['Daily Recoveries'] / population_million) * 1
data['Deaths per Million'] = (data['Daily Deaths'] / population_million) * 1

# Group by Month and aggregate the data
monthly_data = data.groupby(data['Date'].dt.to_period('M')).agg({
    'Daily Tests': 'sum',
    'Daily Cases': 'sum',
    'Tests per Thousand': 'sum',
    'Cases per Thousand': 'sum',
    'Tests per Million': 'sum',
    'Cases per Million': 'sum',
}).reset_index()

# Rename the 'Date' column to 'Month' and format it
monthly_data['Month'] = monthly_data['Date'].dt.strftime('%B')
monthly_data = monthly_data.drop(columns=['Date'])

# Calculate the positive rate
monthly_data['Positive Rate'] = (monthly_data['Daily Cases'] / monthly_data['Daily Tests']) * 100

# Rearrange the columns to match the format in the image
monthly_data = monthly_data[['Month', 'Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate']]



# Display the DataFrame as a formatted table
styled_table = monthly_data.style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', '#2d4154'), ('color', 'white')]}]
).background_gradient(cmap='Blues', subset=['Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate'])

# Show the styled DataFrame
styled_table
# Out:
# <style type="text/css">
# #T_396be thead th {
#   background-color: #2d4154;
#   color: white;
# }
# #T_396be_row0_col1, #T_396be_row0_col2, #T_396be_row0_col3, #T_396be_row0_col4, #T_396be_row0_col5, #T_396be_row0_col6, #T_396be_row6_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_396be_row0_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_396be_row1_col1, #T_396be_row1_col3, #T_396be_row1_col5 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_396be_row1_col2, #T_396be_row1_col4, #T_396be_row1_col6 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_396be_row1_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_396be_row2_col1, #T_396be_row2_col3, #T_396be_row2_col5 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_396be_row2_col2, #T_396be_row2_col4, #T_396be_row2_col6 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_396be_row2_col7 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_396be_row3_col1, #T_396be_row3_col3, #T_396be_row3_col5 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_396be_row3_col2, #T_396be_row3_col4, #T_396be_row3_col6 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_396be_row3_col7 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_396be_row4_col1, #T_396be_row4_col2, #T_396be_row4_col3, #T_396be_row4_col4, #T_396be_row4_col5, #T_396be_row4_col6, #T_396be_row4_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_396be_row5_col1, #T_396be_row5_col3, #T_396be_row5_col5 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_396be_row5_col2, #T_396be_row5_col4, #T_396be_row5_col6 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_396be_row5_col7 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_396be_row6_col1, #T_396be_row6_col3, #T_396be_row6_col5 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_396be_row6_col2, #T_396be_row6_col4, #T_396be_row6_col6 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# </style>
# <table id="T_396be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_396be_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_396be_level0_col1" class="col_heading level0 col1" >Daily Tests</th>
#       <th id="T_396be_level0_col2" class="col_heading level0 col2" >Daily Cases</th>
#       <th id="T_396be_level0_col3" class="col_heading level0 col3" >Tests per Thousand</th>
#       <th id="T_396be_level0_col4" class="col_heading level0 col4" >Cases per Thousand</th>
#       <th id="T_396be_level0_col5" class="col_heading level0 col5" >Tests per Million</th>
#       <th id="T_396be_level0_col6" class="col_heading level0 col6" >Cases per Million</th>
#       <th id="T_396be_level0_col7" class="col_heading level0 col7" >Positive Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_396be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_396be_row0_col0" class="data row0 col0" >February</td>
#       <td id="T_396be_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_396be_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_396be_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_396be_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_396be_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_396be_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_396be_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_396be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_396be_row1_col0" class="data row1 col0" >March</td>
#       <td id="T_396be_row1_col1" class="data row1 col1" >1934.000000</td>
#       <td id="T_396be_row1_col2" class="data row1 col2" >158.000000</td>
#       <td id="T_396be_row1_col3" class="data row1 col3" >0.008791</td>
#       <td id="T_396be_row1_col4" class="data row1 col4" >0.000718</td>
#       <td id="T_396be_row1_col5" class="data row1 col5" >8.790909</td>
#       <td id="T_396be_row1_col6" class="data row1 col6" >0.718182</td>
#       <td id="T_396be_row1_col7" class="data row1 col7" >8.169597</td>
#     </tr>
#     <tr>
#       <th id="T_396be_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_396be_row2_col0" class="data row2 col0" >April</td>
#       <td id="T_396be_row2_col1" class="data row2 col1" >7609.000000</td>
#       <td id="T_396be_row2_col2" class="data row2 col2" >891.000000</td>
#       <td id="T_396be_row2_col3" class="data row2 col3" >0.034586</td>
#       <td id="T_396be_row2_col4" class="data row2 col4" >0.004050</td>
#       <td id="T_396be_row2_col5" class="data row2 col5" >34.586364</td>
#       <td id="T_396be_row2_col6" class="data row2 col6" >4.050000</td>
#       <td id="T_396be_row2_col7" class="data row2 col7" >11.709817</td>
#     </tr>
#     <tr>
#       <th id="T_396be_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_396be_row3_col0" class="data row3 col0" >May</td>
#       <td id="T_396be_row3_col1" class="data row3 col1" >14445.000000</td>
#       <td id="T_396be_row3_col2" class="data row3 col2" >3344.000000</td>
#       <td id="T_396be_row3_col3" class="data row3 col3" >0.065659</td>
#       <td id="T_396be_row3_col4" class="data row3 col4" >0.015200</td>
#       <td id="T_396be_row3_col5" class="data row3 col5" >65.659091</td>
#       <td id="T_396be_row3_col6" class="data row3 col6" >15.200000</td>
#       <td id="T_396be_row3_col7" class="data row3 col7" >23.149879</td>
#     </tr>
#     <tr>
#       <th id="T_396be_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_396be_row4_col0" class="data row4 col0" >June</td>
#       <td id="T_396be_row4_col1" class="data row4 col1" >24154.000000</td>
#       <td id="T_396be_row4_col2" class="data row4 col2" >6083.000000</td>
#       <td id="T_396be_row4_col3" class="data row4 col3" >0.109791</td>
#       <td id="T_396be_row4_col4" class="data row4 col4" >0.027650</td>
#       <td id="T_396be_row4_col5" class="data row4 col5" >109.790909</td>
#       <td id="T_396be_row4_col6" class="data row4 col6" >27.650000</td>
#       <td id="T_396be_row4_col7" class="data row4 col7" >25.184234</td>
#     </tr>
#     <tr>
#       <th id="T_396be_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_396be_row5_col0" class="data row5 col0" >July</td>
#       <td id="T_396be_row5_col1" class="data row5 col1" >12245.000000</td>
#       <td id="T_396be_row5_col2" class="data row5 col2" >1267.000000</td>
#       <td id="T_396be_row5_col3" class="data row5 col3" >0.055659</td>
#       <td id="T_396be_row5_col4" class="data row5 col4" >0.005759</td>
#       <td id="T_396be_row5_col5" class="data row5 col5" >55.659091</td>
#       <td id="T_396be_row5_col6" class="data row5 col6" >5.759091</td>
#       <td id="T_396be_row5_col7" class="data row5 col7" >10.347080</td>
#     </tr>
#     <tr>
#       <th id="T_396be_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_396be_row6_col0" class="data row6 col0" >August</td>
#       <td id="T_396be_row6_col1" class="data row6 col1" >14051.000000</td>
#       <td id="T_396be_row6_col2" class="data row6 col2" >1136.000000</td>
#       <td id="T_396be_row6_col3" class="data row6 col3" >0.063868</td>
#       <td id="T_396be_row6_col4" class="data row6 col4" >0.005164</td>
#       <td id="T_396be_row6_col5" class="data row6 col5" >63.868182</td>
#       <td id="T_396be_row6_col6" class="data row6 col6" >5.163636</td>
#       <td id="T_396be_row6_col7" class="data row6 col7" >8.084834</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Prepare data for ML models
X = data[['Daily Tests']]  # Feature (you can choose other features as well)
y_cases = data['Daily Cases']  # Target for cases
y_deaths = data['Daily Deaths']  # Target for deaths

# Split the data into training and testing sets
X_train, X_test, y_cases_train, y_cases_test = train_test_split(X, y_cases, test_size=0.2, random_state=42)
_, _, y_deaths_train, y_deaths_test = train_test_split(X, y_deaths, test_size=0.2, random_state=42)

# Linear Regression Model for Daily Cases
lr_model = LinearRegression()
lr_model.fit(X_train, y_cases_train)
cases_predictions = lr_model.predict(X_test)

# Random Forest Model for Daily Deaths
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_deaths_train)
deaths_predictions = rf_model.predict(X_test)

# Display the results
print(f"Linear Regression Model for Cases: {cases_predictions}")
print(f"Random Forest Model for Deaths: {deaths_predictions}")
# Out:
# Linear Regression Model for Cases: [ 21.72291422  89.4240535   -8.53579433 -14.63107376  54.37619683
#  133.83251785  35.00191581  78.53962596 -10.93036839  14.75688059
#   65.91369002  85.28797103  12.57999509  93.12475886  21.28753712
#   34.13116161 129.26105828   8.22622407  16.9337661  191.73767234
#  173.23414553  65.47831292  55.68232813   3.43707596  69.17901828
#   46.75709755 -14.63107376 200.22752582 110.53984292 119.24738495
#   62.64836176 -14.63107376 103.57380929 107.05682611  33.47809596
#   89.64174205  69.39670683  95.30164437]
# Random Forest Model for Deaths: [0.34       0.49       0.18       0.         0.59       1.6
#  0.03       1.4785     0.08       1.26       0.11       0.705
#  0.62       0.         0.34       0.02       1.47       0.55
#  1.26       1.76       4.92       0.11       0.99       0.
#  0.475      0.81816667 0.         7.53       1.36       0.03
#  0.68       0.         0.77       0.76       0.02       0.49
#  1.195      0.        ]
