# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file="COVID-19 Daily.xlsx"
#For Pakistan
data=pd.read_excel(file,sheet_name=["KP"])
data

# Access a specific sheet
data = data['KP']

# %%
# question1
null_values = data.isnull().sum()
column_info = data.info()
descriptive_stats = data.describe()

null_values, column_info, descriptive_stats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              188 non-null    datetime64[ns]
#  1   Daily Tests       175 non-null    float64
#  2   Daily Cases       177 non-null    float64
#  3   Daily Recoveries  175 non-null    float64
#  4   Daily Deaths      175 non-null    object
#  5   Lockdown          38 non-null     object
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 8.9+ KB
# (Date                  0
#  Daily Tests          13
#  Daily Cases          11
#  Daily Recoveries     13
#  Daily Deaths         13
#  Lockdown            150
#  dtype: int64,
#  None,
#                        Date  Daily Tests  Daily Cases  Daily Recoveries
#  count                  188   175.000000   177.000000        175.000000
#  mean   2020-05-29 12:00:00  1580.862857   204.056497        194.160000
# ...

# %%
# Fill missing values using forward fill and backward fill
data.fillna(method='ffill', inplace=True)
data.fillna(method='bfill', inplace=True)

# Re-check for missing values
print(data.isnull().sum())
# Out:
# Date                0
# Daily Tests         0
# Daily Cases         0
# Daily Recoveries    0
# Daily Deaths        0
# Lockdown            0
# dtype: int64
# C:\Users\malia\AppData\Local\Temp\ipykernel_13996\872869718.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# C:\Users\malia\AppData\Local\Temp\ipykernel_13996\872869718.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill', inplace=True)

# %%
# question02

total_tests = data['Daily Tests'].sum()
print(f'Total Tests Performed : {total_tests}')
# Out:
# Total Tests Performed : 276651.0

# %%
# Trend Line Graph
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Tests'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Tests'], color='purple')
plt.title('Scatter Plot of Daily Tests')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Tests'], color='orange')
plt.title('Bar Graph of Daily Tests')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()


average_tests = data['Daily Tests'].mean()

# Above-average in red, below-average in green
colors = ['red' if x > average_tests else 'green' for x in data['Daily Tests']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Tests'], color=colors)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Testing')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Trend Line Graph for Daily Cases
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Cases'], label='Daily Cases', color='blue')
plt.title('Daily Cases Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram for Daily Cases
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Cases'], color='purple')
plt.title('Scatter Plot of Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph for Daily Cases
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Cases'], color='orange')
plt.title('Bar Graph of Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Calculate average for daily cases
average_cases = data['Daily Cases'].mean()

# Color scheme: Above-average in red, below-average in green
colors_cases = ['red' if x > average_cases else 'green' for x in data['Daily Cases']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Cases'], color=colors_cases)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Trend Line Graph for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Recoveries'], label='Daily Recoveries', color='blue')
plt.title('Daily Recoveries Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Recoveries'], color='purple')
plt.title('Scatter Plot of Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Recoveries'], color='orange')
plt.title('Bar Graph of Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()


# Calculate average for daily recoveries
average_recoveries = data['Daily Recoveries'].mean()

# Color scheme: Above-average in red, below-average in green
colors_recoveries = ['red' if x > average_recoveries else 'green' for x in data['Daily Recoveries']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Recoveries'], color=colors_recoveries)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Convert the dataset into weekly stats (only numeric columns)
weekly_stats = data.resample('W-Mon', on='Date').sum(numeric_only=True).reset_index().sort_values(by='Date')

# Convert the dataset into monthly stats (only numeric columns)
monthly_stats = data.resample('M', on='Date').sum(numeric_only=True).reset_index().sort_values(by='Date')

# Save the weekly and monthly stats
weekly_stats.to_excel('Weekly_StatsKP.xlsx', index=False)
monthly_stats.to_excel('Monthly_StatsKP.xlsx', index=False)

# Display max and min values for weekly and monthly stats
print("Weekly Stats - Max:")
print(weekly_stats.max(numeric_only=True))

print("Weekly Stats - Min:")
print(weekly_stats.min(numeric_only=True))

print("Monthly Stats - Max:")
print(monthly_stats.max(numeric_only=True))

print("Monthly Stats - Min:")
print(monthly_stats.min(numeric_only=True))
# Out:
# Weekly Stats - Max:
# Daily Tests         24284.0
# Daily Cases          4466.0
# Daily Recoveries     5757.0
# dtype: float64
# Weekly Stats - Min:
# Daily Tests         0.0
# Daily Cases         0.0
# Daily Recoveries    0.0
# dtype: float64
# Monthly Stats - Max:
# Daily Tests         87268.0
# Daily Cases         16571.0
# Daily Recoveries    15562.0
# dtype: float64
# Monthly Stats - Min:
# Daily Tests         0.0
# Daily Cases         0.0
# Daily Recoveries    0.0
# dtype: float64
# C:\Users\malia\AppData\Local\Temp\ipykernel_13996\3404985569.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_stats = data.resample('M', on='Date').sum(numeric_only=True).reset_index().sort_values(by='Date')

# %%
population_million = 220

# Convert the 'Date' column to datetime format if not already
data['Date'] = pd.to_datetime(data['Date'])

# Convert relevant columns to numeric, forcing errors to NaN where necessary
numeric_columns = ['Daily Tests', 'Daily Cases', 'Daily Recoveries', 'Daily Deaths']
data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Calculate Per Thousand and Per Million stats
data['Tests per Thousand'] = (data['Daily Tests'] / population_million) / 1000
data['Cases per Thousand'] = (data['Daily Cases'] / population_million) / 1000
data['Recoveries per Thousand'] = (data['Daily Recoveries'] / population_million) / 1000
data['Deaths per Thousand'] = (data['Daily Deaths'] / population_million) / 1000

data['Tests per Million'] = (data['Daily Tests'] / population_million)
data['Cases per Million'] = (data['Daily Cases'] / population_million)
data['Recoveries per Million'] = (data['Daily Recoveries'] / population_million)
data['Deaths per Million'] = (data['Daily Deaths'] / population_million)

# Group by Month and aggregate the data
monthly_data = data.groupby(data['Date'].dt.to_period('M')).agg({
    'Daily Tests': 'sum',
    'Daily Cases': 'sum',
    'Tests per Thousand': 'sum',
    'Cases per Thousand': 'sum',
    'Tests per Million': 'sum',
    'Cases per Million': 'sum',
}).reset_index()

# Rename the 'Date' column to 'Month' and format it
monthly_data['Month'] = monthly_data['Date'].dt.strftime('%B')
monthly_data = monthly_data.drop(columns=['Date'])

# Calculate the positive rate
monthly_data['Positive Rate'] = (monthly_data['Daily Cases'] / monthly_data['Daily Tests']) * 100

# Rearrange the columns to match the format in the image
monthly_data = monthly_data[['Month', 'Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate']]

# Display the DataFrame as a formatted table
styled_table = monthly_data.style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', '#2d4154'), ('color', 'white')]}]
).background_gradient(cmap='Blues', subset=['Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate'])

# Show the styled DataFrame
styled_table
# Out:
# <style type="text/css">
# #T_9d700 thead th {
#   background-color: #2d4154;
#   color: white;
# }
# #T_9d700_row0_col1, #T_9d700_row0_col2, #T_9d700_row0_col3, #T_9d700_row0_col4, #T_9d700_row0_col5, #T_9d700_row0_col6, #T_9d700_row6_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9d700_row0_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9d700_row1_col1, #T_9d700_row1_col3, #T_9d700_row1_col5 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_9d700_row1_col2, #T_9d700_row1_col4, #T_9d700_row1_col6 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_9d700_row1_col7 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_9d700_row2_col1, #T_9d700_row2_col3, #T_9d700_row2_col5 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_9d700_row2_col2, #T_9d700_row2_col4, #T_9d700_row2_col6 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_9d700_row2_col7 {
#   background-color: #1663aa;
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Prepare data for ML models
X = data[['Daily Tests']]  # Feature (you can choose other features as well)
y_cases = data['Daily Cases']  # Target for cases
y_deaths = data['Daily Deaths']  # Target for deaths

# Drop rows with missing values in X, y_cases, or y_deaths
data_clean = data.dropna(subset=['Daily Tests', 'Daily Cases', 'Daily Deaths'])
X_clean = data_clean[['Daily Tests']]
y_cases_clean = data_clean['Daily Cases']
y_deaths_clean = data_clean['Daily Deaths']

# Split the data into training and testing sets
X_train, X_test, y_cases_train, y_cases_test = train_test_split(X_clean, y_cases_clean, test_size=0.2, random_state=42)
_, _, y_deaths_train, y_deaths_test = train_test_split(X_clean, y_deaths_clean, test_size=0.2, random_state=42)

# Linear Regression Model for Daily Cases
lr_model = LinearRegression()
lr_model.fit(X_train, y_cases_train)
cases_predictions = lr_model.predict(X_test)

# Random Forest Model for Daily Deaths
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_deaths_train)
deaths_predictions = rf_model.predict(X_test)

# Display the results
print(f"Linear Regression Model for Cases: {cases_predictions}")
print(f"Random Forest Model for Deaths: {deaths_predictions}")
# Out:
# Linear Regression Model for Cases: [399.65315088 205.9306823   91.73122581 272.7104074  239.74940547
#   15.76163029 154.58993952 215.73321076 339.7351957  298.6871078
#   92.22135223  64.65174096 211.32207295  40.63554624  67.8375627
#   15.76163029 209.11650405 378.21011989 234.84814124  17.96719919
#  286.55647884 344.88152314  15.63909869 232.76510395  31.81327064
#  154.22234471  15.63909869 208.62637763 308.73469947 228.59902935
#   15.63909869 233.62282519 134.6172878  148.21829603 111.58134593
#   21.76567897 255.80104581 175.78790731]
# Random Forest Model for Deaths: [19.51        6.12        4.39        4.85       11.17934524  0.
#   6.31        7.3        12.35        3.07        4.39        3.62
#  10.28        2.385       3.7         0.         12.72       17.87
#   8.86345238  1.28       13.96        8.59        0.          7.36428571
#   0.86        6.31        0.         12.72       17.65        2.72
# ...
