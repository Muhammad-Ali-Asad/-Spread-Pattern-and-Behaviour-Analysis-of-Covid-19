# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file="COVID-19 Daily.xlsx"
#For Pakistan
data=pd.read_excel(file,sheet_name=["Punjab"])
data

# Access a specific sheet
data = data['Punjab']

# %%
# question1
null_values = data.isnull().sum()
column_info = data.info()
descriptive_stats = data.describe()

null_values, column_info, descriptive_stats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              188 non-null    datetime64[ns]
#  1   Daily Tests       175 non-null    float64
#  2   Daily Cases       177 non-null    float64
#  3   Daily Recoveries  175 non-null    float64
#  4   Daily Deaths      175 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 7.5 KB
# (Date                 0
#  Daily Tests         13
#  Daily Cases         11
#  Daily Recoveries    13
#  Daily Deaths        13
#  dtype: int64,
#  None,
#                        Date   Daily Tests  Daily Cases  Daily Recoveries  \
#  count                  188    175.000000   177.000000        175.000000
#  mean   2020-05-29 12:00:00   5383.920000   547.073446        528.565714
#  min    2020-02-26 00:00:00      0.000000     0.000000          0.000000
#  25%    2020-04-12 18:00:00   2347.000000   109.000000         11.000000
#  50%    2020-05-29 12:00:00   5798.000000   276.000000         69.000000
#  75%    2020-07-15 06:00:00   7730.000000   730.000000        351.500000
#  max    2020-08-31 00:00:00  11739.000000  2705.000000      12802.000000
#  std                    NaN   3112.625699   633.000225       1528.589153
#
#         Daily Deaths
#  count    175.000000
#  mean      12.565714
#  min        0.000000
#  25%        1.000000
#  50%        5.000000
#  75%       17.000000
#  max       86.000000
#  std       17.131841  )

# %%
# Fill missing values using forward fill and backward fill
data.fillna(method='ffill', inplace=True)
data.fillna(method='bfill', inplace=True)

# Re-check for missing values
print(data.isnull().sum())
# Out:
# Date                0
# Daily Tests         0
# Daily Cases         0
# Daily Recoveries    0
# Daily Deaths        0
# dtype: int64
# C:\Users\malia\AppData\Local\Temp\ipykernel_15300\872869718.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# C:\Users\malia\AppData\Local\Temp\ipykernel_15300\872869718.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill', inplace=True)

# %%
# question02

total_tests = data['Daily Tests'].sum()
print(f'Total Tests Performed : {total_tests}')
# Out:
# Total Tests Performed : 942186.0

# %%
# Trend Line Graph
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Tests'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Tests'], color='purple')
plt.title('Scatter Plot of Daily Tests')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Tests'], color='orange')
plt.title('Bar Graph of Daily Tests')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()


average_tests = data['Daily Tests'].mean()

# Above-average in red, below-average in green
colors = ['red' if x > average_tests else 'green' for x in data['Daily Tests']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Tests'], color=colors)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Testing')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Trend Line Graph for Daily Cases
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Cases'], label='Daily Cases', color='blue')
plt.title('Daily Cases Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram for Daily Cases
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Cases'], color='purple')
plt.title('Scatter Plot of Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph for Daily Cases
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Cases'], color='orange')
plt.title('Bar Graph of Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Calculate average for daily cases
average_cases = data['Daily Cases'].mean()

# Color scheme: Above-average in red, below-average in green
colors_cases = ['red' if x > average_cases else 'green' for x in data['Daily Cases']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Cases'], color=colors_cases)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Trend Line Graph for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Daily Recoveries'], label='Daily Recoveries', color='blue')
plt.title('Daily Recoveries Trend in Pakistan')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Scatter Diagram for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Recoveries'], color='purple')
plt.title('Scatter Plot of Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Bar Graph for Daily Recoveries
plt.figure(figsize=(12, 6))
plt.bar(data['Date'], data['Daily Recoveries'], color='orange')
plt.title('Bar Graph of Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()


# Calculate average for daily recoveries
average_recoveries = data['Daily Recoveries'].mean()

# Color scheme: Above-average in red, below-average in green
colors_recoveries = ['red' if x > average_recoveries else 'green' for x in data['Daily Recoveries']]

plt.figure(figsize=(12, 6))
plt.scatter(data['Date'], data['Daily Recoveries'], color=colors_recoveries)
plt.title('Above-Average (Red) and Below-Average (Green) Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# question03

# Convert the dataset into weekly stats
weekly_stats = data.resample('W-Mon', on='Date').sum().reset_index().sort_values(by='Date')

# Convert the dataset into monthly stats
monthly_stats = data.resample('M', on='Date').sum().reset_index().sort_values(by='Date')

# Save the weekly and monthly stats
weekly_stats.to_excel('Weekly_StatsPunjab.xlsx', index=False)
monthly_stats.to_excel('Monthly_StatsPunjab.xlsx', index=False)

# Display max and min values for weekly and monthly stats
print("Weekly Stats - Max:")
print(weekly_stats.max())

print("Weekly Stats - Min:")
print(weekly_stats.min())

print("Monthly Stats - Max:")
print(monthly_stats.max())

print("Monthly Stats - Min:")
print(monthly_stats.min())
# Out:
# Weekly Stats - Max:
# Date                2020-08-31 00:00:00
# Daily Tests                     68752.0
# Daily Cases                     15059.0
# Daily Recoveries                19907.0
# Daily Deaths                      414.0
# dtype: object
# Weekly Stats - Min:
# Date                2020-03-02 00:00:00
# Daily Tests                         0.0
# Daily Cases                         0.0
# Daily Recoveries                    0.0
# Daily Deaths                        0.0
# dtype: object
# Monthly Stats - Max:
# Date                2020-08-31 00:00:00
# Daily Tests                    262763.0
# Daily Cases                     50022.0
# Daily Recoveries                55053.0
# Daily Deaths                     1265.0
# dtype: object
# Monthly Stats - Min:
# Date                2020-02-29 00:00:00
# Daily Tests                         0.0
# Daily Cases                         0.0
# Daily Recoveries                    0.0
# Daily Deaths                        0.0
# dtype: object
# C:\Users\malia\AppData\Local\Temp\ipykernel_15300\408847835.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_stats = data.resample('M', on='Date').sum().reset_index().sort_values(by='Date')

# %%
# question04

population_million = 220

# Convert the 'Date' column to datetime format if not already
data['Date'] = pd.to_datetime(data['Date'])

# Calculate Per Thousand and Per Million stats
data['Tests per Thousand'] = (data['Daily Tests'] / population_million) / 1000
data['Cases per Thousand'] = (data['Daily Cases'] / population_million) / 1000
data['Recoveries per Thousand'] = (data['Daily Recoveries'] / population_million) / 1000
data['Deaths per Thousand'] = (data['Daily Deaths'] / population_million) / 1000

data['Tests per Million'] = (data['Daily Tests'] / population_million) * 1
data['Cases per Million'] = (data['Daily Cases'] / population_million) * 1
data['Recoveries per Million'] = (data['Daily Recoveries'] / population_million) * 1
data['Deaths per Million'] = (data['Daily Deaths'] / population_million) * 1

# Group by Month and aggregate the data
monthly_data = data.groupby(data['Date'].dt.to_period('M')).agg({
    'Daily Tests': 'sum',
    'Daily Cases': 'sum',
    'Tests per Thousand': 'sum',
    'Cases per Thousand': 'sum',
    'Tests per Million': 'sum',
    'Cases per Million': 'sum',
}).reset_index()

# Rename the 'Date' column to 'Month' and format it
monthly_data['Month'] = monthly_data['Date'].dt.strftime('%B')
monthly_data = monthly_data.drop(columns=['Date'])

# Calculate the positive rate
monthly_data['Positive Rate'] = (monthly_data['Daily Cases'] / monthly_data['Daily Tests']) * 100

# Rearrange the columns to match the format in the image
monthly_data = monthly_data[['Month', 'Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate']]



# Display the DataFrame as a formatted table
styled_table = monthly_data.style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', '#2d4154'), ('color', 'white')]}]
).background_gradient(cmap='Blues', subset=['Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate'])

# Show the styled DataFrame
styled_table
# Out:
# <style type="text/css">
# #T_5e11a thead th {
#   background-color: #2d4154;
#   color: white;
# }
# #T_5e11a_row0_col1, #T_5e11a_row0_col2, #T_5e11a_row0_col3, #T_5e11a_row0_col4, #T_5e11a_row0_col5, #T_5e11a_row0_col6, #T_5e11a_row6_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5e11a_row0_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_5e11a_row1_col1, #T_5e11a_row1_col3, #T_5e11a_row1_col5 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_5e11a_row1_col2, #T_5e11a_row1_col4, #T_5e11a_row1_col6 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_5e11a_row1_col7 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_5e11a_row2_col1, #T_5e11a_row2_col3, #T_5e11a_row2_col5 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_5e11a_row2_col2, #T_5e11a_row2_col4, #T_5e11a_row2_col6 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_5e11a_row2_col7 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T
row4_col0" class="data row4 col0" >June</td>
#       <td id="T_5e11a_row4_col1" class="data row4 col1" >262763.000000</td>
#       <td id="T_5e11a_row4_col2" class="data row4 col2" >50022.000000</td>
#       <td id="T_5e11a_row4_col3" class="data row4 col3" >1.194377</td>
#       <td id="T_5e11a_row4_col4" class="data row4 col4" >0.227373</td>
#       <td id="T_5e11a_row4_col5" class="data row4 col5" >1194.377273</td>
#       <td id="T_5e11a_row4_col6" class="data row4 col6" >227.372727</td>
#       <td id="T_5e11a_row4_col7" class="data row4 col7" >19.036927</td>
#     </tr>
#     <tr>
#       <th id="T_5e11a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5e11a_row5_col0" class="data row5 col0" >July</td>
#       <td id="T_5e11a_row5_col1" class="data row5 col1" >231708.000000</td>
#       <td id="T_5e11a_row5_col2" class="data row5 col2" >16795.000000</td>
#       <td id="T_5e11a_row5_col3" class="data row5 col3" >1.053218</td>
#       <td id="T_5e11a_row5_col4" class="data row5 col4" >0.076341</td>
#       <td id="T_5e11a_row5_col5" class="data row5 col5" >1053.218182</td>
#       <td id="T_5e11a_row5_col6" class="data row5 col6" >76.340909</td>
#       <td id="T_5e11a_row5_col7" class="data row5 col7" >7.248347</td>
#     </tr>
#     <tr>
#       <th id="T_5e11a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e11a_row6_col0" class="data row6 col0" >August</td>
#       <td id="T_5e11a_row6_col1" class="data row6 col1" >224520.000000</td>
#       <td id="T_5e11a_row6_col2" class="data row6 col2" >3775.000000</td>
#       <td id="T_5e11a_row6_col3" class="data row6 col3" >1.020545</td>
#       <td id="T_5e11a_row6_col4" class="data row6 col4" >0.017159</td>
#       <td id="T_5e11a_row6_col5" class="data row6 col5" >1020.545455</td>
#       <td id="T_5e11a_row6_col6" class="data row6 col6" >17.159091</td>
#       <td id="T_5e11a_row6_col7" class="data row6 col7" >1.681365</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Prepare data for ML models
X = data[['Daily Tests']]  # Feature (you can choose other features as well)
y_cases = data['Daily Cases']  # Target for cases
y_deaths = data['Daily Deaths']  # Target for deaths

# Split the data into training and testing sets
X_train, X_test, y_cases_train, y_cases_test = train_test_split(X, y_cases, test_size=0.2, random_state=42)
_, _, y_deaths_train, y_deaths_test = train_test_split(X, y_deaths, test_size=0.2, random_state=42)

# Linear Regression Model for Daily Cases
lr_model = LinearRegression()
lr_model.fit(X_train, y_cases_train)
cases_predictions = lr_model.predict(X_test)

# Random Forest Model for Daily Deaths
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_deaths_train)
deaths_predictions = rf_model.predict(X_test)

# Display the results
print(f"Linear Regression Model for Cases: {cases_predictions}")
print(f"Random Forest Model for Deaths: {deaths_predictions}")
# Out:
# Linear Regression Model for Cases: [1066.73723819  743.18373484  -35.6961762   -35.6961762   433.71706554
#  1104.22818235  154.08786364  529.77374497  -35.6961762   788.99367549
#   130.68375353  894.8113108   103.39744505  552.29049546  210.65703975
#   327.34483047 1094.35630652  358.51333731   81.10253447  821.82598163
#   522.23118816  590.00327954  884.05207535  -35.6961762   257.9089398
#   964.69088129  -35.6961762   865.41752322   16.10344192  670.97484534
#   538.86918113  -35.6961762   742.29637522  593.21995818  565.9336497
#   972.34435806  372.93293122  813.839745  ]
# Random Forest Model for Deaths: [ 6.61        2.17        0.128674    0.128674    7.99       52.72
#   3.09       15.99        0.128674    3.01        1.11       44.29
#   0.77       20.95333333  1.57742857 11.62       63.63        7.68
#   0.99       35.02       12.98        7.94       31.32        0.128674
#   5.71       50.91        0.128674   26.14        0.13        8.92
#  13.54        0.128674    2.4         6.23        8.69333333 41.53
#   7.19       25.1       ]
